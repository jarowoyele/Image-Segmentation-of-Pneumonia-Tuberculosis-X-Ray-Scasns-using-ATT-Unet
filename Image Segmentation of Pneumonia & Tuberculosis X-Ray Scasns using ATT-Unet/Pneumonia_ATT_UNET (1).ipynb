# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import os
import PIL
## checking for xrays and their respective masks
from glob import glob
import re
from collections import defaultdict
import pandas as pd
import matplotlib.pyplot as plt
from numpy import zeros, random
from tqdm import tqdm
from keras.metrics import MeanIoU
from tensorflow.image import resize
from keras.preprocessing.image import load_img, img_to_array
from keras.optimizers import *
# Model
from keras.models import Model, Sequential, load_model
from keras.layers import Conv2D, Conv2DTranspose, concatenate, MaxPool2D, Dropout, BatchNormalization, Layer, Input, add, multiply, UpSampling2D

# Model Viz
from tensorflow.keras.utils import plot_model
# Callback
from keras.callbacks import Callback
from keras import backend as K

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_path = '/content/drive/My Drive/Med_Seg/Datasets/Pneum/images/'
# Use defaultdict to store image paths and mask paths
data = defaultdict(list)
image_paths = sorted(glob(root_path + f"*.png"))
mask_paths = []
for path in image_paths:
    mask_path = path.replace('images','masks')
    # mask_path = mask_path.replace('.png','_seg0.png')
    data['image_path'].append(path)
    data['mask_path'].append(mask_path)
print(f"Total Number of Images  : {len(image_paths)}")
# Out:
# Total Number of Images  : 1345

# %%
# Create a DataFrame from the defaultdict
df = pd.DataFrame(data)

# Print the total number of images
print(f"Total Number of Images  : {len(image_paths)}")

# Display the DataFrame
print(df)
# Out:
# Total Number of Images  : 1345
#                                              image_path  \
# 0     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 2     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 3     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 4     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# ...                                                 ...
# 1340  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1341  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1342  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1343  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1344  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
#
#                                               mask_path
# 0     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 2     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 3     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 4     /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# ...                                                 ...
# 1340  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1341  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1342  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1343  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1344  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
#
# [1345 rows x 2 columns]

# %%
df = df.iloc[0:800]

# %%
df
# Out:
#                                             image_path  \
# 0    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 2    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 3    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 4    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# ..                                                 ...
# 795  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 796  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 797  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 798  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 799  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
#
#                                              mask_path
# 0    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 1    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 2    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 3    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 4    /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# ..                                                 ...
# 795  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 796  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 797  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 798  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
# 799  /content/drive/My Drive/Med_Seg/Datasets/Pneum...
#
# [800 rows x 2 columns]

# %%
xray_num = 5
img_path = df["image_path"][xray_num]
mask_path = df["mask_path"][xray_num]

img = PIL.Image.open(img_path)
mask = PIL.Image.open(mask_path)

fig = plt.figure(figsize = (10,10))

ax1 = fig.add_subplot(2,2,1)
ax1.imshow(img, cmap = "gray")
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(mask, cmap = "gray")

# %%
def load_image(path):
    img = resize( img_to_array( load_img(path) )/255. , (256,256))
    return img

# %%
images = zeros(shape=(len(df["image_path"]), 256, 256, 3))
masks = zeros(shape=(len(df["mask_path"]), 256, 256, 3))
for n, (img_path, mask_path) in tqdm(enumerate(zip(df["image_path"], df["mask_path"])), desc="Loading"):
    images[n] = load_image(img_path)
    masks[n] = load_image(mask_path)
# Out:
# Loading: 800it [04:31,  2.95it/s]

# %%
from sklearn.model_selection import train_test_split
img_train, img_test, mask_train, mask_test = train_test_split(images, masks, test_size = 0.2, random_state= 42)

# %%
class Encoder(Layer):

    def __init__(self, filters, rate, pooling=True, **kwargs):
        super(Encoder, self).__init__(**kwargs)

        self.filters = filters
        self.rate = rate
        self.pooling = pooling

        self.c1 = Conv2D(filters, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', activation='relu')
        self.drop = Dropout(rate)
        self.c2 = Conv2D(filters, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', activation='relu')
        self.pool = MaxPool2D()

    def call(self, X):
        x = self.c2(self.drop(self.c1(X)))
        if self.pooling:
            y = self.pool(x)
            return y, x
        else:
            return x

    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "filters":self.filters,
            "rate":self.rate,
            "pooling":self.pooling,
        }

# %%
class Decoder(Layer):

    def __init__(self, filters, rate, **kwargs):
        super(Decoder, self).__init__(**kwargs)

        self.filters = filters
        self.rate = rate

        self.cT = Conv2DTranspose(filters, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', activation='relu')
        self.net = Encoder(filters, rate, pooling=False)

    def call(self, X):
        x, skip_x = X
        x = self.cT(x)

        c = concatenate([x, skip_x])
        f = self.net(c)
        return f

    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "filters":self.filters,
            "rate":self.rate
        }

# %%
class AttentionGate(Layer):

    def __init__(self, filters, **kwargs):
        super(AttentionGate, self).__init__(**kwargs)

        self.filters = filters

        self.normal = Conv2D(filters, kernel_size=3, strides=1, padding='same', kernel_initializer='he_normal', activation='relu')
        self.down = Conv2D(filters, kernel_size=3, strides=2, padding='same', kernel_initializer='he_normal', activation='relu')

        self.learn = Conv2D(1, kernel_size=1, strides=1, activation='sigmoid')
        self.resample = UpSampling2D()

    def call(self, X):
        x, skip_x = X

        x = self.normal(x)
        skip = self.down(skip_x)
        a = add([x, skip])

        l = self.learn(a)
        l = self.resample(l)

        f = multiply([l, skip_x])
        return f

    def get_config(self):
        base_config = super().get_config()
        return {
            **base_config,
            "filters":self.filters
        }

# %%
from tensorflow.keras import backend as K
from keras.metrics import Precision, Recall
# Inputs
image_input = Input(shape=(256,256,3), name="InputImage")

# Encoder Phase
p1, c1 = Encoder(32, 0.1, name="EncoderBlock1")(image_input)
p2, c2 = Encoder(64, 0.1, name="EncoderBlock2")(p1)
p3, c3 = Encoder(128, 0.2, name="EncoderBlock3")(p2)
p4, c4 = Encoder(256, 0.2, name="EncoderBlock4")(p3)

# Latent Representation
encoding = Encoder(512, 0.3, pooling=False, name="Encoding")(p4)

# Deocder + Attention Phase
a1 = AttentionGate(256, name="Attention1")([encoding, c4])
d1 = Decoder(256, 0.2, name="DecoderBlock1")([encoding, a1])

a2 = AttentionGate(128, name="Attention2")([d1, c3])
d2 = Decoder(128, 0.2, name="DecoderBlock2")([d1, a2])

a3 = AttentionGate(64, name="Attention3")([d2, c2])
d3 = Decoder(64, 0.2, name="DecoderBlock3")([d2, a3])

a4 = AttentionGate(32, name="Attention4")([d3, c1])
d4 = Decoder(32, 0.1, name="DecoderBlock4")([d3, a4])

# Output Layer
mask_out = Conv2D(3, kernel_size=1, strides=1, activation='sigmoid', padding='same', name="MaskOut")(d4)

def dice_coef(y_true, y_pred):
    y_true_f = tf.keras.layers.Flatten()(y_true)
    y_pred_f = tf.keras.layers.Flatten()(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# Model
att_unet = Model(
    inputs=[image_input], outputs=[mask_out], name="AttentionUNet"
)

# Compile
att_unet.compile(optimizer=Adam(learning_rate=5*1e-4), loss="binary_crossentropy",
                  metrics=[dice_coef,Precision(),Recall(),'binary_accuracy',Precision(),Recall(), MeanIoU(num_classes=2, name="IoU")])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'Encoding', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'encoder_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'encoder_2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'encoder_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(

# %%
plot_model(att_unet, "AttentionUNet.png", show_shapes=True)

# %%
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
history = att_unet.fit(x = img_train,
                    y = mask_train,
                    validation_data = (img_test, mask_test),
                    epochs = 30,
                    batch_size = 16,
                   callbacks = [earlystopping])
# Out:
# Epoch 1/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 110s 990ms/step - IoU: 0.2942 - binary_accuracy: 0.7448 - dice_coef: 0.2819 - loss: 0.5459 - precision: 0.2209 - precision_1: 0.2209 - recall: 0.0419 - recall_1: 0.0419 - val_IoU: 0.3483 - val_binary_accuracy: 0.7678 - val_dice_coef: 0.3537 - val_loss: 0.4649 - val_precision: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_recall: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 61s 394ms/step - IoU: 0.2944 - binary_accuracy: 0.7698 - dice_coef: 0.3861 - loss: 0.3889 - precision: 0.2017 - precision_1: 0.2017 - recall: 1.0805e-05 - recall_1: 1.0805e-05 - val_IoU: 0.3483 - val_binary_accuracy: 0.7697 - val_dice_coef: 0.3916 - val_loss: 0.4381 - val_precision: 0.9708 - val_precision_1: 0.9708 - val_recall: 0.0086 - val_recall_1: 0.0086
# Epoch 3/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 396ms/step - IoU: 0.2937 - binary_accuracy: 0.8134 - dice_coef: 0.5115 - loss: 0.2928 - precision: 0.9440 - precision_1: 0.9440 - recall: 0.2107 - recall_1: 0.2107 - val_IoU: 0.3483 - val_binary_accuracy: 0.9346 - val_dice_coef: 0.5163 - val_loss: 0.2813 - val_precision: 0.9103 - val_precision_1: 0.9103 - val_recall: 0.7970 - val_recall_1: 0.7970
# Epoch 4/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 393ms/step - IoU: 0.2932 - binary_accuracy: 0.9324 - dice_coef: 0.6061 - loss: 0.2366 - precision: 0.8928 - precision_1: 0.8928 - recall: 0.8084 - recall_1: 0.8084 - val_IoU: 0.3483 - val_binary_accuracy: 0.9461 - val_dice_coef: 0.7179 - val_loss: 0.1863 - val_precision: 0.8755 - val_precision_1: 0.8755 - val_recall: 0.8950 - val_recall_1: 0.8950
# Epoch 5/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 401ms/step - IoU: 0.2947 - binary_accuracy: 0.9517 - dice_coef: 0.8452 - loss: 0.1218 - precision: 0.9125 - precision_1: 0.9125 - recall: 0.8739 - recall_1: 0.8739 - val_IoU: 0.3483 - val_binary_accuracy: 0.9562 - val_dice_coef: 0.7492 - val_loss: 0.1648 - val_precision: 0.8879 - val_precision_1: 0.8879 - val_recall: 0.9284 - val_recall_1: 0.9284
# Epoch 6/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - IoU: 0.2965 - binary_accuracy: 0.9615 - dice_coef: 0.8754 - loss: 0.0962 - precision: 0.9292 - precision_1: 0.9292 - recall: 0.9023 - recall_1: 0.9023 - val_IoU: 0.3483 - val_binary_accuracy: 0.9592 - val_dice_coef: 0.8162 - val_loss: 0.1217 - val_precision: 0.8999 - val_precision_1: 0.8999 - val_recall: 0.9277 - val_recall_1: 0.9277
# Epoch 7/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 401ms/step - IoU: 0.3030 - binary_accuracy: 0.9672 - dice_coef: 0.8952 - loss: 0.0811 - precision: 0.9406 - precision_1: 0.9406 - recall: 0.9167 - recall_1: 0.9167 - val_IoU: 0.3483 - val_binary_accuracy: 0.9600 - val_dice_coef: 0.8275 - val_loss: 0.1107 - val_precision: 0.9371 - val_precision_1: 0.9371 - val_recall: 0.8872 - val_recall_1: 0.8872
# Epoch 8/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 396ms/step - IoU: 0.3010 - binary_accuracy: 0.9654 - dice_coef: 0.8901 - loss: 0.0862 - precision: 0.9379 - precision_1: 0.9379 - recall: 0.9122 - recall_1: 0.9122 - val_IoU: 0.3483 - val_binary_accuracy: 0.9682 - val_dice_coef: 0.8507 - val_loss: 0.0951 - val_precision: 0.9434 - val_precision_1: 0.9434 - val_recall: 0.9182 - val_recall_1: 0.9182
# Epoch 9/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - IoU: 0.3225 - binary_accuracy: 0.9704 - dice_coef: 0.9060 - loss: 0.0733 - precision: 0.9444 - precision_1: 0.9444 - recall: 0.9257 - recall_1: 0.9257 - val_IoU: 0.3485 - val_binary_accuracy: 0.9700 - val_dice_coef: 0.8608 - val_loss: 0.0924 - val_precision: 0.9291 - val_precision_1: 0.9291 - val_recall: 0.9427 - val_recall_1: 0.9427
# Epoch 10/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 397ms/step - IoU: 0.3386 - binary_accuracy: 0.9720 - dice_coef: 0.9117 - loss: 0.0690 - precision: 0.9485 - precision_1: 0.9485 - recall: 0.9307 - recall_1: 0.9307 - val_IoU: 0.3483 - val_binary_accuracy: 0.9710 - val_dice_coef: 0.8735 - val_loss: 0.0836 - val_precision: 0.9602 - val_precision_1: 0.9602 - val_recall: 0.9129 - val_recall_1: 0.9129
# Epoch 11/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 400ms/step - IoU: 0.3631 - binary_accuracy: 0.9753 - dice_coef: 0.9214 - loss: 0.0600 - precision: 0.9560 - precision_1: 0.9560 - recall: 0.9358 - recall_1: 0.9358 - val_IoU: 0.3483 - val_binary_accuracy: 0.9577 - val_dice_coef: 0.8399 - val_loss: 0.1040 - val_precision: 0.9806 - val_precision_1: 0.9806 - val_recall: 0.8343 - val_recall_1: 0.8343
# Epoch 12/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 405ms/step - IoU: 0.3216 - binary_accuracy: 0.9704 - dice_coef: 0.9091 - loss: 0.0720 - precision: 0.9524 - precision_1: 0.9524 - recall: 0.9204 - recall_1: 0.9204 - val_IoU: 0.3488 - val_binary_accuracy: 0.9755 - val_dice_coef: 0.8979 - val_loss: 0.0678 - val_precision: 0.9544 - val_precision_1: 0.9544 - val_recall: 0.9395 - val_recall_1: 0.9395
# Epoch 13/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - IoU: 0.3902 - binary_accuracy: 0.9792 - dice_coef: 0.9347 - loss: 0.0506 - precision: 0.9627 - precision_1: 0.9627 - recall: 0.9477 - recall_1: 0.9477 - val_IoU: 0.3484 - val_binary_accuracy: 0.9699 - val_dice_coef: 0.8863 - val_loss: 0.0781 - val_precision: 0.9640 - val_precision_1: 0.9640 - val_recall: 0.9039 - val_recall_1: 0.9039
# Epoch 14/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - IoU: 0.3502 - binary_accuracy: 0.9771 - dice_coef: 0.9270 - loss: 0.0553 - precision: 0.9644 - precision_1: 0.9644 - recall: 0.9354 - recall_1: 0.9354 - val_IoU: 0.3485 - val_binary_accuracy: 0.9772 - val_dice_coef: 0.9038 - val_loss: 0.0656 - val_precision: 0.9661 - val_precision_1: 0.9661 - val_recall: 0.9347 - val_recall_1: 0.9347
# Epoch 15/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 402ms/step - IoU: 0.3919 - binary_accuracy: 0.9806 - dice_coef: 0.9396 - loss: 0.0469 - precision: 0.9648 - precision_1: 0.9648 - recall: 0.9520 - recall_1: 0.9520 - val_IoU: 0.3581 - val_binary_accuracy: 0.9783 - val_dice_coef: 0.9164 - val_loss: 0.0626 - val_precision: 0.9555 - val_precision_1: 0.9555 - val_recall: 0.9509 - val_recall_1: 0.9509
# Epoch 16/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 402ms/step - IoU: 0.4287 - binary_accuracy: 0.9812 - dice_coef: 0.9411 - loss: 0.0451 - precision: 0.9652 - precision_1: 0.9652 - recall: 0.9536 - recall_1: 0.9536 - val_IoU: 0.3537 - val_binary_accuracy: 0.9781 - val_dice_coef: 0.9176 - val_loss: 0.0611 - val_precision: 0.9587 - val_precision_1: 0.9587 - val_recall: 0.9465 - val_recall_1: 0.9465
# Epoch 17/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - IoU: 0.4204 - binary_accuracy: 0.9829 - dice_coef: 0.9468 - loss: 0.0411 - precision: 0.9673 - precision_1: 0.9673 - recall: 0.9588 - recall_1: 0.9588 - val_IoU: 0.3489 - val_binary_accuracy: 0.9782 - val_dice_coef: 0.9066 - val_loss: 0.0652 - val_precision: 0.9612 - val_precision_1: 0.9612 - val_recall: 0.9441 - val_recall_1: 0.9441
# Epoch 18/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 403ms/step - IoU: 0.4252 - binary_accuracy: 0.9828 - dice_coef: 0.9442 - loss: 0.0411 - precision: 0.9696 - precision_1: 0.9696 - recall: 0.9553 - recall_1: 0.9553 - val_IoU: 0.3746 - val_binary_accuracy: 0.9810 - val_dice_coef: 0.9368 - val_loss: 0.0527 - val_precision: 0.9661 - val_precision_1: 0.9661 - val_recall: 0.9515 - val_recall_1: 0.9515
# Epoch 19/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 402ms/step - IoU: 0.4431 - binary_accuracy: 0.9828 - dice_coef: 0.9475 - loss: 0.0414 - precision: 0.9680 - precision_1: 0.9680 - recall: 0.9580 - recall_1: 0.9580 - val_IoU: 0.3778 - val_binary_accuracy: 0.9798 - val_dice_coef: 0.9324 - val_loss: 0.0559 - val_precision: 0.9624 - val_precision_1: 0.9624 - val_recall: 0.9501 - val_recall_1: 0.9501
# Epoch 20/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 407ms/step - IoU: 0.4667 - binary_accuracy: 0.9845 - dice_coef: 0.9513 - loss: 0.0372 - precision: 0.9712 - precision_1: 0.9712 - recall: 0.9615 - recall_1: 0.9615 - val_IoU: 0.4126 - val_binary_accuracy: 0.9803 - val_dice_coef: 0.9337 - val_loss: 0.0548 - val_precision: 0.9466 - val_precision_1: 0.9466 - val_recall: 0.9698 - val_recall_1: 0.9698
# Epoch 21/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 405ms/step - IoU: 0.4986 - binary_accuracy: 0.9853 - dice_coef: 0.9545 - loss: 0.0349 - precision: 0.9715 - precision_1: 0.9715 - recall: 0.9649 - recall_1: 0.9649 - val_IoU: 0.3964 - val_binary_accuracy: 0.9814 - val_dice_coef: 0.9385 - val_loss: 0.0488 - val_precision: 0.9675 - val_precision_1: 0.9675 - val_recall: 0.9517 - val_recall_1: 0.9517
# Epoch 22/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 405ms/step - IoU: 0.5269 - binary_accuracy: 0.9862 - dice_coef: 0.9575 - loss: 0.0326 - precision: 0.9738 - precision_1: 0.9738 - recall: 0.9661 - recall_1: 0.9661 - val_IoU: 0.4141 - val_binary_accuracy: 0.9826 - val_dice_coef: 0.9404 - val_loss: 0.0466 - val_precision: 0.9672 - val_precision_1: 0.9672 - val_recall: 0.9576 - val_recall_1: 0.9576
# Epoch 23/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 20s 400ms/step - IoU: 0.5399 - binary_accuracy: 0.9860 - dice_coef: 0.9571 - loss: 0.0328 - precision: 0.9726 - precision_1: 0.9726 - recall: 0.9675 - recall_1: 0.9675 - val_IoU: 0.4544 - val_binary_accuracy: 0.9818 - val_dice_coef: 0.9433 - val_loss: 0.0467 - val_precision: 0.9517 - val_precision_1: 0.9517 - val_recall: 0.9708 - val_recall_1: 0.9708
# Epoch 24/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 403ms/step - IoU: 0.5741 - binary_accuracy: 0.9875 - dice_coef: 0.9619 - loss: 0.0293 - precision: 0.9745 - precision_1: 0.9745 - recall: 0.9716 - recall_1: 0.9716 - val_IoU: 0.3964 - val_binary_accuracy: 0.9817 - val_dice_coef: 0.9374 - val_loss: 0.0500 - val_precision: 0.9628 - val_precision_1: 0.9628 - val_recall: 0.9581 - val_recall_1: 0.9581
# Epoch 25/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 405ms/step - IoU: 0.5597 - binary_accuracy: 0.9874 - dice_coef: 0.9603 - loss: 0.0298 - precision: 0.9761 - precision_1: 0.9761 - recall: 0.9691 - recall_1: 0.9691 - val_IoU: 0.4262 - val_binary_accuracy: 0.9830 - val_dice_coef: 0.9444 - val_loss: 0.0474 - val_precision: 0.9714 - val_precision_1: 0.9714 - val_recall: 0.9550 - val_recall_1: 0.9550
# Epoch 26/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - IoU: 0.5680 - binary_accuracy: 0.9883 - dice_coef: 0.9639 - loss: 0.0274 - precision: 0.9774 - precision_1: 0.9774 - recall: 0.9727 - recall_1: 0.9727 - val_IoU: 0.4880 - val_binary_accuracy: 0.9846 - val_dice_coef: 0.9507 - val_loss: 0.0422 - val_precision: 0.9713 - val_precision_1: 0.9713 - val_recall: 0.9622 - val_recall_1: 0.9622
# Epoch 27/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - IoU: 0.5932 - binary_accuracy: 0.9889 - dice_coef: 0.9648 - loss: 0.0260 - precision: 0.9764 - precision_1: 0.9764 - recall: 0.9749 - recall_1: 0.9749 - val_IoU: 0.5587 - val_binary_accuracy: 0.9838 - val_dice_coef: 0.9502 - val_loss: 0.0474 - val_precision: 0.9637 - val_precision_1: 0.9637 - val_recall: 0.9665 - val_recall_1: 0.9665
# Epoch 28/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - IoU: 0.6202 - binary_accuracy: 0.9890 - dice_coef: 0.9657 - loss: 0.0259 - precision: 0.9774 - precision_1: 0.9774 - recall: 0.9750 - recall_1: 0.9750 - val_IoU: 0.5537 - val_binary_accuracy: 0.9838 - val_dice_coef: 0.9507 - val_loss: 0.0488 - val_precision: 0.9673 - val_precision_1: 0.9673 - val_recall: 0.9628 - val_recall_1: 0.9628
# Epoch 29/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 406ms/step - IoU: 0.6419 - binary_accuracy: 0.9899 - dice_coef: 0.9686 - loss: 0.0238 - precision: 0.9795 - precision_1: 0.9795 - recall: 0.9763 - recall_1: 0.9763 - val_IoU: 0.5291 - val_binary_accuracy: 0.9836 - val_dice_coef: 0.9523 - val_loss: 0.0463 - val_precision: 0.9725 - val_precision_1: 0.9725 - val_recall: 0.9564 - val_recall_1: 0.9564
# Epoch 30/30
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 16s 412ms/step - IoU: 0.6376 - binary_accuracy: 0.9901 - dice_coef: 0.9697 - loss: 0.0232 - precision: 0.9805 - precision_1: 0.9805 - recall: 0.9768 - recall_1: 0.9768 - val_IoU: 0.5964 - val_binary_accuracy: 0.9827 - val_dice_coef: 0.9502 - val_loss: 0.0480 - val_precision: 0.9499 - val_precision_1: 0.9499 - val_recall: 0.9769 - val_recall_1: 0.9769

# %%
def get_metrics(history):
    fig = plt.figure(figsize = (10,10))
    plt.subplot(2,2,1)
    plt.plot(history.history["loss"], label = "training loss")
    plt.plot(history.history["val_loss"], label = "validation loss")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Binary Cross Entropy ")

    plt.subplot(2,2,2)
    plt.plot(history.history["dice_coef"], label = "training dice coefficient")
    plt.plot(history.history["val_dice_coef"], label = "validation dice coefficient")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Dice Coefficient")

get_metrics(history = history)

# %%
def get_metrics(history):
    fig = plt.figure(figsize = (10,10))
    plt.subplot(2,2,1)
    plt.plot(history.history["binary_accuracy"], label = "training accuracy")
    plt.plot(history.history["val_binary_accuracy"], label = "validation accuracy")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy ")

    plt.subplot(2,2,2)
    plt.plot(history.history["IoU"], label = "training IoU")
    plt.plot(history.history["val_IoU"], label = "validation IoU")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("IoU")
get_metrics(history = history)

# %%
def get_metrics(history):
    fig = plt.figure(figsize = (10,10))
    plt.subplot(2,2,1)
    plt.plot(history.history["precision_1"], label = "training Precision")
    plt.plot(history.history["val_precision_1"], label = "validation Precision")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Precision ")

    plt.subplot(2,2,2)
    plt.plot(history.history["recall_1"], label = "training Recall")
    plt.plot(history.history["val_recall_1"], label = "validation Recall")
    plt.legend()
    plt.xlabel("Epochs")
    plt.ylabel("Recall")
get_metrics(history = history)

# %%
accuracy = history.history["val_binary_accuracy"]
precision = history.history["val_precision_1"]
recall = history.history["val_recall_1"]
iou = history.history["val_IoU"]
dice_coef = history.history["val_dice_coef"]
print("The Accuracy of the UNET model:",round(accuracy[-1],2))
print("The Precision of the UNET model:",round(precision[-1],2))
print("The Recall of the UNET model:",round(recall[-1],2))
print("The IOU Score of the UNET model:",round(iou[-1],2))
print("The Dice Score of the UNET model:",round(dice_coef[-1],2))
# Out:
# The Accuracy of the UNET model: 0.98
# The Precision of the UNET model: 0.95
# The Recall of the UNET model: 0.98
# The IOU Score of the UNET model: 0.6
# The Dice Score of the UNET model: 0.95

# %%
for i in range(5):
  id = random.randint(0,len(images))
  image,mask = images[id], masks[id]
  pred_mask = att_unet.predict(tf.expand_dims(image, axis=0))[0]

  fig = plt.figure(figsize = (15,10))

  plt.subplot(1,4,1)
  plt.imshow(pred_mask, cmap = "Blues")
  plt.title("Prediciton")
  plt.axis("off")

  plt.subplot(1,4,2)
  plt.imshow(masks[id],cmap = "Blues")
  plt.title("Original Mask");
  plt.axis("off")

  plt.subplot(1,4,3)
  plt.imshow(images[id], cmap = "gray")
  plt.title("Original")
  plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
accuracy = history.history["val_binary_accuracy"]
precision = history.history["val_precision_1"]
recall = history.history["val_recall_1"]
iou = history.history["val_IoU"]
dice_coef = history.history["val_dice_coef"]
print("The Accuracy of the UNET model:",round(accuracy[-1],2))
print("The Precision of the UNET model:",round(precision[-1],2))
print("The Recall of the UNET model:",round(recall[-1],2))
print("The IOU Score of the UNET model:",round(iou[-1],2))
print("The Dice Score of the UNET model:",round(dice_coef[-1],2))
# Out:
# The Accuracy of the UNET model: 0.98
# The Precision of the UNET model: 0.95
# The Recall of the UNET model: 0.98
# The IOU Score of the UNET model: 0.6
# The Dice Score of the UNET model: 0.95

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have the variables `pred_mask` and `mask` for a single sample

# Flatten the masks
y_true_flat = mask.flatten()
y_pred_flat = (pred_mask.flatten() > 0.5).astype(int)  # Binary masks with thresholding

# Compute the confusion matrix
cm = confusion_matrix(y_true_flat, y_pred_flat)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Display the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm_normalized, annot=True, fmt='.2%', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Normalized Confusion Matrix for Attention U-Net Model')
plt.show()

# %%
import tensorflow as tf
from sklearn.metrics import roc_curve, auc
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have the variables `pred_mask` and `mask` for a single sample

# Flatten the ground truth and predicted mask
y_true_flat = mask.flatten()
y_pred_flat = pred_mask.flatten()  # Keep predictions as probabilities

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_true_flat, y_pred_flat)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
